# %% [markdown]
# # Last Mile Delivery Analysis- Task 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
deliveries=pd.read_csv("E:\Intership-GEN AI\Intern Projects\Data Analysis Tasks\Last Mile Delivery Analysis-Task 2\Data\diminos_data_v2\deliveries.csv")
deliveries
# Out:
#           order_id                     time_stamp            status
# 0        321230114  2020-12-11 00:01:29.000000000           Pending
# 1        321230114  2020-12-11 00:06:29.000000000  Out For Delivery
# 2        321230114  2020-12-11 00:19:13.299151076         Delivered
# 3        321230115  2020-12-11 00:36:02.000000000           Pending
# 4        321230115  2020-12-11 00:41:02.000000000  Out For Delivery
# ...            ...                            ...               ...
# 1363003  321684446  2024-01-31 23:58:08.494812502         Delivered
# 1363004  321684449  2024-02-01 00:00:46.000000000  Out For Delivery
# 1363005  321684448  2024-02-01 00:03:05.000000000  Out For Delivery
# 1363006  321684449  2024-02-01 00:14:56.997433391         Delivered
# 1363007  321684448  2024-02-01 00:17:50.996900711         Delivered
#
# [1363008 rows x 3 columns]

# %%
deliveries.head()
# Out:
#     order_id                     time_stamp            status
# 0  321230114  2020-12-11 00:01:29.000000000           Pending
# 1  321230114  2020-12-11 00:06:29.000000000  Out For Delivery
# 2  321230114  2020-12-11 00:19:13.299151076         Delivered
# 3  321230115  2020-12-11 00:36:02.000000000           Pending
# 4  321230115  2020-12-11 00:41:02.000000000  Out For Delivery

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363008 entries, 0 to 1363007
# Data columns (total 3 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   order_id    1363008 non-null  int64
#  1   time_stamp  1363008 non-null  object
#  2   status      1363008 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 31.2+ MB

# %%
order_items=pd.read_csv("E:\Intership-GEN AI\Intern Projects\Data Analysis Tasks\Last Mile Delivery Analysis-Task 2\Data\diminos_data_v2\order_items.csv")
order_items
# Out:
#          order_id                items_ordered
# 0       321230114  ['p_025', 'p_032', 'p_037']
# 1       321230115           ['p_017', 'p_012']
# 2       321230116           ['p_027', 'p_037']
# 3       321230117           ['p_004', 'p_029']
# 4       321230118           ['p_017', 'p_037']
# ...           ...                          ...
# 454331  321684445  ['p_002', 'p_006', 'p_037']
# 454332  321684446           ['p_015', 'p_013']
# 454333  321684447           ['p_009', 'p_016']
# 454334  321684448  ['p_007', 'p_003', 'p_037']
# 454335  321684449           ['p_022', 'p_037']
#
# [454336 rows x 2 columns]

# %%
order_items.head()
# Out:
#     order_id                items_ordered
# 0  321230114  ['p_025', 'p_032', 'p_037']
# 1  321230115           ['p_017', 'p_012']
# 2  321230116           ['p_027', 'p_037']
# 3  321230117           ['p_004', 'p_029']
# 4  321230118           ['p_017', 'p_037']

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454336 entries, 0 to 454335
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_id       454336 non-null  int64
#  1   items_ordered  454336 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ MB

# %%
orders=pd.read_csv("E:\Intership-GEN AI\Intern Projects\Data Analysis Tasks\Last Mile Delivery Analysis-Task 2\Data\diminos_data_v2\orders.csv")
orders
# Out:
#          order_id      order_placed_at
# 0       321230114  2020-12-11 00:01:29
# 1       321230115  2020-12-11 00:36:02
# 2       321230116  2020-12-11 00:55:01
# 3       321230117  2020-12-11 01:05:27
# 4       321230118  2020-12-11 01:14:20
# ...           ...                  ...
# 454331  321684445  2024-01-31 23:27:51
# 454332  321684446  2024-01-31 23:40:14
# 454333  321684447  2024-01-31 23:36:08
# 454334  321684448  2024-01-31 23:58:05
# 454335  321684449  2024-01-31 23:55:46
#
# [454336 rows x 2 columns]

# %%
orders.head()
# Out:
#     order_id      order_placed_at
# 0  321230114  2020-12-11 00:01:29
# 1  321230115  2020-12-11 00:36:02
# 2  321230116  2020-12-11 00:55:01
# 3  321230117  2020-12-11 01:05:27
# 4  321230118  2020-12-11 01:14:20

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454336 entries, 0 to 454335
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   order_id         454336 non-null  int64
#  1   order_placed_at  454336 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ MB

# %%
products=pd.read_csv("E:\Intership-GEN AI\Intern Projects\Data Analysis Tasks\Last Mile Delivery Analysis-Task 2\Data\diminos_data_v2\products.csv")
products
# Out:
#    item_id category                      Item     Size  Price
# 0    p_001      Veg                Margherita  Regular    109
# 1    p_002      Veg                Margherita   Medium    245
# 2    p_003      Veg                Margherita    Large    455
# 3    p_004      Veg  Double Cheese Margherita  Regular    215
# 4    p_005      Veg  Double Cheese Margherita   Medium    385
# 5    p_006      Veg  Double Cheese Margherita    Large    619
# 6    p_007      Veg                Farm House  Regular    265
# 7    p_008      Veg                Farm House   Medium    469
# 8    p_009      Veg                Farm House    Large    705
# 9    p_010      Veg             Deluxe Veggie  Regular    219
# 10   p_011      Veg             Deluxe Veggie   Medium    385
# 11   p_012      Veg             Deluxe Veggie    Large    619
# 12   p_013      Veg             Cheese N Corn  Regular    179
# 13   p_014      Veg             Cheese N Corn   Medium    319
# ...

# %%
products.head()
# Out:
#   item_id category                      Item     Size  Price
# 0   p_001      Veg                Margherita  Regular    109
# 1   p_002      Veg                Margherita   Medium    245
# 2   p_003      Veg                Margherita    Large    455
# 3   p_004      Veg  Double Cheese Margherita  Regular    215
# 4   p_005      Veg  Double Cheese Margherita   Medium    385

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   37 non-null     object
#  1   category  37 non-null     object
#  2   Item      37 non-null     object
#  3   Size      37 non-null     object
#  4   Price     37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %% [markdown]
# 1.What is the average Delivery Time (in minutes) taken by the store to deliver the Pizza?

# %%
order_store=deliveries[deliveries.status=="Delivered"]

# %%
avg_time=pd.merge(order_store,orders,how='inner',on='order_id')
avg_time.head()
# Out:
#     order_id                     time_stamp     status      order_placed_at
# 0  321230114  2020-12-11 00:19:13.299151076  Delivered  2020-12-11 00:01:29
# 1  321230115  2020-12-11 00:59:18.054846609  Delivered  2020-12-11 00:36:02
# 2  321230116  2020-12-11 01:13:52.153042625  Delivered  2020-12-11 00:55:01
# 3  321230117  2020-12-11 01:22:44.430088094  Delivered  2020-12-11 01:05:27
# 4  321230118  2020-12-11 01:32:27.488575946  Delivered  2020-12-11 01:14:20

# %%
orders.head()
# Out:
#     order_id      order_placed_at
# 0  321230114  2020-12-11 00:01:29
# 1  321230115  2020-12-11 00:36:02
# 2  321230116  2020-12-11 00:55:01
# 3  321230117  2020-12-11 01:05:27
# 4  321230118  2020-12-11 01:14:20

# %%
orders['order_placed_at']=pd.to_datetime(orders['order_placed_at'])
orders.head()
# Out:
#     order_id     order_placed_at
# 0  321230114 2020-12-11 00:01:29
# 1  321230115 2020-12-11 00:36:02
# 2  321230116 2020-12-11 00:55:01
# 3  321230117 2020-12-11 01:05:27
# 4  321230118 2020-12-11 01:14:20

# %%
deliveries=deliveries[deliveries['status']=='Delivered']

avg_time=pd.merge(delivered,orders,how='inner',on='order_id')
avg_time.head()

diff=avg_time.order_placed_at - avg_time.time_stamp

list=[]
for i in diff:
    list.append(abs(i).total_seconds()/60)
    
np.round(np.array(list).mean(),2)
# Out:
# 20.65

# %% [markdown]
# 2.What is the 99th percentile Delivery Time (in minutes) taken by the store to deliver the Pizza?

# %%
percentile_99 = np.percentile(list, 99)
print(f"The 99th percentile delivery time is {percentile_99:.2f} minutes.")
# Out:
# The 99th percentile delivery time is 30.90 minutes.

# %% [markdown]
# 4.What is the order id with the maximum delivery time?

# %%
avg_time['delivery_time']=list
avg_time
# Out:
#          order_id                    time_stamp     status  \
# 0       321230114 2020-12-11 00:19:13.299151076  Delivered
# 1       321230115 2020-12-11 00:59:18.054846609  Delivered
# 2       321230116 2020-12-11 01:13:52.153042625  Delivered
# 3       321230117 2020-12-11 01:22:44.430088094  Delivered
# 4       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...           ...                           ...        ...
# 454331  321684443 2024-01-31 23:50:06.640104742  Delivered
# 454332  321684447 2024-01-31 23:56:35.426400154  Delivered
# 454333  321684446 2024-01-31 23:58:08.494812502  Delivered
# 454334  321684449 2024-02-01 00:14:56.997433391  Delivered
# 454335  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#            order_placed_at  delivery_time
# 0      2020-12-11 00:01:29      17.738319
# 1      2020-12-11 00:36:02      23.267581
# 2      2020-12-11 00:55:01      18.852551
# 3      2020-12-11 01:05:27      17.290501
# ...

# %%
avg_time[avg_time['delivery_time']==avg_time['delivery_time'].max()]
# Out:
#          order_id                    time_stamp     status  \
# 398957  321629049 2023-09-21 16:52:49.724687723  Delivered
#
#            order_placed_at  delivery_time
# 398957 2023-09-21 15:49:55      62.912078

# %% [markdown]
# 5.How many pizza's were ordered between 1st January and 31st January 2024 (INCLUSIVE)?

# %%
filtered_orders = avg_time[(avg_time['order_placed_at'] >= '2024-01-01 00:00:00') & (avg_time['order_placed_at'] <= '2024-01-31 23:59:59')]
num_pizzas_ordered = filtered_orders['order_id'].nunique()

print("Number of pizzas ordered between January 1st and January 31st, 2024 (inclusive):", num_pizzas_ordered)
# Out:
# Number of pizzas ordered between January 1st and January 31st, 2024 (inclusive): 12304

# %% [markdown]
# 6.How many order took more than 30 minutes to deliver between 1st January and 31st January 2024 (INCLUSIVE)?

# %%
above_30=filtered_orders[filtered_orders["delivery_time"] >30]
above_30
# Out:
#          order_id                    time_stamp     status  \
# 442105  321672219 2024-01-01 07:40:00.050788143  Delivered
# 442134  321672246 2024-01-01 10:42:08.274877203  Delivered
# 442281  321672395 2024-01-01 19:51:39.281358734  Delivered
# 442380  321672493 2024-01-02 08:37:27.696347889  Delivered
# 442396  321672506 2024-01-02 09:32:23.416695505  Delivered
# ...           ...                           ...        ...
# 453916  321684028 2024-01-30 23:15:57.900528163  Delivered
# 454022  321684128 2024-01-31 09:28:43.508245394  Delivered
# 454158  321684266 2024-01-31 14:03:26.613185573  Delivered
# 454265  321684378 2024-01-31 18:35:39.707616698  Delivered
# 454314  321684428 2024-01-31 21:40:13.177156302  Delivered
#
#            order_placed_at  delivery_time
# 442105 2024-01-01 07:09:58      30.034180
# 442134 2024-01-01 10:09:42      32.437915
# 442281 2024-01-01 19:19:02      32.621356
# 442380 2024-01-02 08:06:48      30.661606
# ...

# %%
len(above_30)
# Out:
# 162

# %% [markdown]
# 7.What is the total amount Pizza store lost in 2023 due to refunds on late deliveries?

# %%
dic={}
for i,j in zip(products['item_id'],products['Price']):
    dic[i]=j

# %%
order_items['items_ordered'] = order_items['items_ordered'].str.replace('[',"",regex= False).str.replace("]","",regex= False).str.replace("'",'',regex= False)

# %%
ordered_amount=[]
for items in order_items['items_ordered']:
    amount=0
    for item in items.split(','):
        amount+= dic[(item.strip())]
    ordered_amount.append(amount)

# %%
order_items['order_amount']=ordered_amount

# %%
refu=avg_time[avg_time['delivery_time']>30]

# %%
refunded_order_amounts=pd.merge(refu,order_items,how='inner',on='order_id')[['order_id','order_placed_at','order_amount']]

# %%
refunded_order_amounts[refunded_order_amounts['order_placed_at'].dt.year==2023]['order_amount'].sum()
# Out:
# 1826393

# %% [markdown]
# 8.In which year Pizza store has lost maximum amount due to refunds on late deliveries?

# %%
refunded_order_amounts['ordered_year']=refunded_order_amounts['order_placed_at'].dt.year

# %%
refunded_order_amounts.groupby(['ordered_year'])[['order_amount']].sum().sort_values(by='order_amount',ascending=False).head(1)
# Out:
#               order_amount
# ordered_year
# 2023               1826393

# %% [markdown]
# 9.How much revenue is generated by the pizza store till date? Don't include the refund amount in revenue.

# %%
revenued_orders=avg_time[avg_time['delivery_time']<=30]

# %%
revenued_orders_amount=pd.merge(revenued_orders,order_items,how='inner',on='order_id')

# %%
revenued_orders_amount['order_amount'].sum()
# Out:
# 402310056

# %% [markdown]
# # 10.(BONUS QUESTION) Which distribution can be used to model the number of orders incoming each hour? If we can somehow model it, which problem for owner of Pizza Store can be solved? (Implement this in a Jupyter Notebook. Upload your implementation on the google drive and share the link below.)

# %%
hour=orders.order_placed_at.dt.hour

# %%
orders["hours"]=hour

# %%
sns.histplot(data=orders,x="hours")
# Out:
# <Axes: xlabel='hours', ylabel='Count'>
